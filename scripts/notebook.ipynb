# %%
import os
import pandas as pd

# Directory containing the CSV files
results_dir = os.path.join('..', 'results')

# Elenco dei file che iniziano con "benchmark" e terminano con ".csv"
benchmark_csvs = [f for f in os.listdir(results_dir) if f.startswith("benchmark") and f.endswith(".csv")]

if not benchmark_csvs:
    raise FileNotFoundError("Nessun file CSV che inizia con 'benchmark' trovato in ../results")

# Seleziona il file con il nome lessicografico maggiore (assunto più recente)
latest_csv = max(benchmark_csvs)
csv_path = os.path.join(results_dir, latest_csv)

print("CSV importato da:", csv_path)

# Importa il CSV in un DataFrame di pandas
df = pd.read_csv(csv_path, delimiter=';')

df.head()
# Out:
# CSV importato da: ../results/benchmark_results_20250320_005312.csv
#   implementation input_string  batch_size regex_pattern  match_result  \
# 0         Triton         0101           1       (0|1)*1             1
# 1         Triton         0100           1       (0|1)*0             1
# 2         Triton        01011           1      (0|1)*11             1
# 3         Triton        01100           1      (0|1)*00             1
# 4         Triton         0101           1          0101             1
#
#    execution_time_ms  kernel_time_ms  mem_transfer_time_ms  memory_used_bytes  \
# 0           1.061678        1.060963                   0.5              10000
# 1           1.056433        1.056194                   0.5              10000
# 2           1.033545        1.033306                   0.5              10000
# 3           1.054287        1.054287                   0.5              10000
# 4           1.055002        1.054525                   0.5              10000
#
#    gpu_util_percent  num_states  match_success  compilation_time_ms  \
# 0               0.0           2           True                  1.0
# 1               0.0           2           True                  1.0
# 2               0.0           2           True                  1.0
# 3               0.0           2           True                  1.0
# 4               0.0           2           True                  1.0
#
#    num_symbols  number_of_accepting_states  start_state
# 0            2                           1            0
# 1            2                           1            0
# 2            2                           1            0
# 3            2                           1            0
# 4            2                           1            0

# %%
df.shape
# Out:
# (112, 16)

# %%
# separa i dati in cuda e triton per implementation
cuda_df = df[df['implementation'] == 'CUDA']
triton_df = df[df['implementation'] == 'Triton']

# %%
cuda_df.head()
# Out:
#    implementation input_string  batch_size regex_pattern  match_result  \
# 57           CUDA         0101           1       (0|1)*1             1
# 58           CUDA         0100           1       (0|1)*0             1
# 59           CUDA        01011           1      (0|1)*11             1
# 60           CUDA        01100           1      (0|1)*00             1
# 61           CUDA         0101           1          0101             1
#
#     execution_time_ms  kernel_time_ms  mem_transfer_time_ms  \
# 57               0.01            0.01                   0.0
# 58               0.01            0.01                   0.0
# 59               0.01            0.01                   0.0
# 60               0.01            0.01                   0.0
# 61               0.01            0.01                   0.0
#
#     memory_used_bytes  gpu_util_percent  num_states  match_success  \
# 57                  0               0.0           3           True
# 58                  0               0.0           3           True
# 59                  0               0.0           3           True
# 60                  0               0.0           3           True
# 61                  0               0.0           3           True
#
#     compilation_time_ms  num_symbols  number_of_accepting_states  start_state
# 57                  0.0            2                           1            0
# 58                  0.0            2                           1            0
# 59                  0.0            2                           1            0
# 60                  0.0            2                           1            0
# 61                  0.0            2                           1            0

# %%
# describe
cuda_df.describe()
# Out:
#        batch_size  match_result  execution_time_ms  kernel_time_ms  \
# count        55.0          55.0              55.00           55.00
# mean          1.0           1.0               0.01            0.01
# std           0.0           0.0               0.00            0.00
# min           1.0           1.0               0.01            0.01
# 25%           1.0           1.0               0.01            0.01
# 50%           1.0           1.0               0.01            0.01
# 75%           1.0           1.0               0.01            0.01
# max           1.0           1.0               0.01            0.01
#
#        mem_transfer_time_ms  memory_used_bytes  gpu_util_percent  num_states  \
# count                  55.0               55.0              55.0        55.0
# mean                    0.0                0.0               0.0         3.0
# std                     0.0                0.0               0.0         0.0
# min                     0.0                0.0               0.0         3.0
# 25%                     0.0                0.0               0.0         3.0
# 50%                     0.0                0.0               0.0         3.0
# 75%                     0.0                0.0               0.0         3.0
# max                     0.0                0.0               0.0         3.0
#
#        compilation_time_ms  num_symbols  number_of_accepting_states  \
# count                 55.0         55.0                        55.0
# mean                   0.0          2.0                         1.0
# std                    0.0          0.0                         0.0
# min                    0.0          2.0                         1.0
# 25%                    0.0          2.0                         1.0
# 50%                    0.0          2.0                         1.0
# 75%                    0.0          2.0                         1.0
# max                    0.0          2.0                         1.0
#
#        start_state
# count         55.0
# mean           0.0
# std            0.0
# min            0.0
# 25%            0.0
# 50%            0.0
# 75%            0.0
# max            0.0

# %%
triton_df.describe()
# Out:
#        batch_size  match_result  execution_time_ms  kernel_time_ms  \
# count        57.0          57.0          57.000000       57.000000
# mean          1.0           1.0           1.057219        1.057022
# std           0.0           0.0           0.031429        0.031359
# min           1.0           1.0           1.007557        1.007318
# 25%           1.0           1.0           1.053810        1.053572
# 50%           1.0           1.0           1.054287        1.054049
# 75%           1.0           1.0           1.054525        1.054287
# max           1.0           1.0           1.284599        1.283884
#
#        mem_transfer_time_ms  memory_used_bytes  gpu_util_percent  num_states  \
# count                  57.0               57.0              57.0        57.0
# mean                    0.5            10000.0               0.0         2.0
# std                     0.0                0.0               0.0         0.0
# min                     0.5            10000.0               0.0         2.0
# 25%                     0.5            10000.0               0.0         2.0
# 50%                     0.5            10000.0               0.0         2.0
# 75%                     0.5            10000.0               0.0         2.0
# max                     0.5            10000.0               0.0         2.0
#
#        compilation_time_ms  num_symbols  number_of_accepting_states  \
# count                 57.0         57.0                        57.0
# mean                   1.0          2.0                         1.0
# std                    0.0          0.0                         0.0
# min                    1.0          2.0                         1.0
# 25%                    1.0          2.0                         1.0
# 50%                    1.0          2.0                         1.0
# 75%                    1.0          2.0                         1.0
# max                    1.0          2.0                         1.0
#
#        start_state
# count         57.0
# mean           0.0
# std            0.0
# min            0.0
# 25%            0.0
# 50%            0.0
# 75%            0.0
# max            0.0
